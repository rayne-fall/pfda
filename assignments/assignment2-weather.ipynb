# %% [markdown]
# # Week 2 Assignment
# ******

# %% [markdown]
# This week's assignment is to take the CSV file provided in the PFDA-courseware repository and creat a Jupyter notebook containing a plot of the temperature of the dry bulbs over time.

# %% [markdown]
# ## Imports
#
# I will be importing three modules for this task: PANDAS, NumPy and matplotlib.

# %%
# import necessary modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading the data

# %%
# read in data
df = pd.read_csv("https://raw.githubusercontent.com/andrewbeattycourseware/PFDA-courseware/refs/heads/main/assignment/weatherreadings1.csv")

# %% [markdown]
# # Plotting temperature versus time

# %%
# create plot
fig, ax = plt.subplots(figsize = (30, 10))

# get variables
temp = df["dryBulbTemperature_Celsius"]
time = df["reportEndDateTime"]
# convert data frames to arrays
temp = temp.to_numpy()
time = time.to_numpy()

# plot variables
ax.plot(time, temp, "*-", linewidth=2)
# label axes
ax.set_xlabel("Time")
ax.set_ylabel("Temperature (C)")
# add title
ax.set_title("Temperature changes of dry bulbs over time")
# add gridlines
ax.grid()
# show plot
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Notes/Issues
#
# The labelling on the x-axis is currently illegible due to the formatting used to record the time each measurement was taken in the original CSV file. This is causing the labels on the plot to overlap with each other. The most practical solution I have found at the moment would be to swap the x and y axes. This would make the labels legible, but would be poor practice as time should be on the x axis (given that it increases at regular intervals, unlike the temperature). Adjusting the size of the figure so that the x axis becomes long enough for the labels to avoid overlapping would be another solution, but in practice the length required for the x axis makes the figure so large that the audience must zoom in on individual sections in order to clearly see the labels. It also takes several seconds to render the larger figure, compared to less than a second for each of the smaller ones.

# %% [markdown]
# ### Alternative Plots

# %%
# create plot
fig, ax = plt.subplots(figsize = (10, 30))

# get variables
temp = df["dryBulbTemperature_Celsius"]
time = df["reportEndDateTime"]
# convert data frames to arrays
temp = temp.to_numpy()
time = time.to_numpy()

# plot variables
ax.plot(temp, time, "*-", linewidth=2)
# label axes
ax.set_xlabel("Temperature (C)")
ax.set_ylabel("Time")
# add title
ax.set_title("Temperature changes of dry bulbs over time")
# add gridlines
ax.grid()
# show plot
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# create plot
fig, ax = plt.subplots(figsize = (275, 50))

# get variables
temp = df["dryBulbTemperature_Celsius"]
time = df["reportEndDateTime"]
# convert data frames to arrays
temp = temp.to_numpy()
time = time.to_numpy()

# plot variables
ax.plot(time, temp, "*-", linewidth=2)
# label axes
ax.set_xlabel("Time")
ax.set_ylabel("Temperature (C)")
# add title
ax.set_title("Temperature changes of dry bulbs over time")
# add gridlines
ax.grid()
# show plot
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# *****
# # End
